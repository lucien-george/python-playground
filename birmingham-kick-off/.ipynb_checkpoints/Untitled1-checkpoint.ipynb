# %% [markdown]
# # Web scraping Le Wagon cities

# %% [markdown]
# ## Importing libraries for web scraping

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Getting the url of the Le Wagon's website

# %%
url = "https://www.lewagon.com/campuses"

# %% [markdown]
# ## Requesting the url of the website using **requests** library

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ## Getting response's status code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## Looking at the response's content

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html class="pages-campuses" lang="en">\n  <head>\n    <title>Our 37 Campuses | Le Wagon</title>\n    <meta name="description" content="Paris, London, Berlin, Montreal, Shanghai, Bali, S\xc3\xa3o Paulo... Discover Le Wagon&#39;s 37 campuses all over the world.">\n\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n    <meta name="robots" content="index, follow">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\n    <link rel="icon" href="https://dwj199mwkel52.cloudfront.net/assets/favicon-2c2100c8c497758008b4271b2be66d5a2182ad8acfdcdde48996dc357e14df54.png" type="image/png" />\n    <link rel="apple-touch-icon" href="https://dwj199mwkel52.cloudfront.net/assets/apple-touch-icon-c29632e03ea4a63a00e432568fe5fc980798a847d1dbccaaa4d04d5634e11f4e.png" />\n\n    <meta property="og:site_name" content="Coding Bootcamp Le Wagon | World&#39;s Best Coding Bootcamp" />\n    <meta property="og:title" content="Our 37 Campuses | Le Wagon" />\n    <meta property="og:type" content="article" />\n    <meta property="og:url" content="https://www.lewagon.com/campuses" />\n    <meta property="og:image" content="https://dwj199mwkel52.cloudfront.net/assets/core/social/campuses-card-1fa2c432e80d289ad9516c19916601703893a5dc61ff8db64cff261d245d56af.jpg" />\n    <meta property="og:description" content="Paris, London, Berlin, Montreal, Shanghai, Bali, S\xc3\xa3o Paulo... Discover Le Wagon&#39;s 37 campuses all over the world." />\n    <meta property="fb:admins" content="548348576" />\n    <meta property="fb:app_id" content="737501859652485" />\n\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:site" content="@Lewagonparis">\n    <meta name="twitter:title" content="Our 37 Campuses | Le Wagon">\n    <meta name="twitter:description" content="Paris, London, Berlin, Montreal, Shanghai, Bali, S\xc3\xa3o Paulo... Discover Le Wagon&#39;s 37 campuses all over the world.">\n    <meta name="twitter:creator" content="@Lewagonparis">\n    <meta name="twitter:image:src" content="https://dwj199mwkel52.cloudfront.net/assets/core/social/campuses-card-1fa2c432e80d289ad9516c19916601703893a5dc61ff8db64cff261d245d56af.jpg">\n\n    <meta name="google-site-verification" content="LnPNLeO2JXVUcf-vJ-TpkNB3ngOGzFHjzj0WfDu82bc" />\n\n      <link rel="canonical" href="/campuses" />\n    <link rel="alternate" hreflang="fr" href="/fr/campuses" />\n    <link rel="alternate" hreflang="es" href="/es/campuses" />\n    <link rel="alternate" hreflang="de" href="/de/campuses" />\n    <link rel="alternate" hreflang="pt-BR" href="/pt-BR/campuses" />\n    <link rel="alternate" hreflang="it" href="/it/campuses" />\n    <link rel="alternate" hreflang="ja" href="/ja/campuses" />\n    <link rel="alternate" hreflang="zh-CN" href="/zh-CN/campuses" />\n\n\n    <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="+NvMV3aaVoh9oQsWAVF3xGlOZDpjmJWlgUlprIBr4DdF3H2X/BQHbWeAQHg9vESHxpQ2PICEZMHZLiegwVkdhg==" />\n    <link rel="stylesheet" media="screen" href="https://dwj199mwkel52.cloudfront.net/packs/frontend_desktop-f5edb12a421412bfb57fdcefeb3d74c2.css" />\n  </head>\n  <body class="pages-campuses" data-controller="modal" data-target="modal.modalOverflow" data-action="keydown->modal#closeWithEsc">\n    \n    \n    <nav class="navbar-wrapper  ">\n  <div class="navbar-container">\n    <a href="/">\n      <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="154" height="48" class="logo" version="1.1" viewBox="0 0 154 48"><g id="logo"><ellipse id="Oval" cx="24.026" cy="24" fill="#FD1015" rx="24.026" ry="24"/><g id="wagon" fill="#FFF" transform="translate(9.842105, 13.590361)"><path id="Combined-Shape" d="M1.45600601,16.524475 C1.43540836,16.6639995 1.3150454,16.7710843 1.169644,16.7710843 C1.16570875,16.7710843 1.16179183,16.7710059 1.15789474,16.7708505 L0.28947368 ...

# %% [markdown]
# ## Creating soup with BeautifulSoup

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="pages-campuses" lang="en">
# <head>
# <title>Our 37 Campuses | Le Wagon</title>
# <meta content="Paris, London, Berlin, Montreal, Shanghai, Bali, São Paulo... Discover Le Wagon's 37 campuses all over the world." name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type">
# <meta content="index, follow" name="robots"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://dwj199mwkel52.cloudfront.net/assets/favicon-2c2100c8c497758008b4271b2be66d5a2182ad8acfdcdde48996dc357e14df54.png" rel="icon" type="image/png"/>
# <link href="https://dwj199mwkel52.cloudfront.net/assets/apple-touch-icon-c29632e03ea4a63a00e432568fe5fc980798a847d1dbccaaa4d04d5634e11f4e.png" rel="apple-touch-icon"/>
# <meta content="Coding Bootcamp Le Wagon | World's Best Coding Bootcamp" property="og:site_name">
# <meta content="Our 37 Campuses | Le Wagon" property="og:title">
# <meta content="article" property="og:type">
# <meta content="https://www.lewagon.com/campuses" property="og:url"/>
# <meta content="https://dwj199mwkel52.cloudfront.net/assets/core/social/campuses-card-1fa2c432e80d289ad9516c19916601703893a5dc61ff8db64cff261d245d56af.jpg" property="og:image"/>
# <meta content="Paris, London, Berlin, Montreal, Shanghai, Bali, São Paulo... Discover Le Wagon's 37 campuses all over the world." property="og:description"/>
# <meta content="548348576" property="fb:admins"/>
# <meta content="737501859652485" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@Lewagonparis" name="twitter:site"/>
# <meta content="Our 37 Campuses | Le Wagon" name="twitter:title"/>
# <meta content="Paris, London, Berlin, Montreal, Shanghai, Bali, São Paulo... Discover Le Wagon's 37 campuses all over the world." name="twitter:description"/>
# <meta content="@Lewagonparis" name="twitter:creator"/>
# <meta content="https://dwj199mwkel52.cloudfront.net/assets/core/social/campuses-card-1fa2c432e80d289ad9516c19916601703893a5dc61ff8db64cff261d245d56af.jpg" name="twitter:image:src"/>
# <meta content="LnPNLeO2JXVUcf-vJ-TpkNB3ngOGzFHjzj0WfDu82bc" name="google-site-verification">
# <link href="/campuses" rel="canonical"/>
# <link href="/fr/campuses" hreflang="fr" rel="alternate"/>
# <link href="/es/campuses" hreflang="es" rel="alternate"/>
# <link href="/de/campuses" hreflang="de" rel="alternate"/>
# <link href="/pt-BR/campuses" hreflang="pt-BR" rel="alternate"/>
# <link href="/it/campuses" hreflang="it" rel="alternate"/>
# <link href="/ja/campuses" hreflang="ja" rel="alternate"/>
# <link href="/zh-CN/campuses" hreflang="zh-CN" rel="alternate"/>
# <meta content="authenticity_token" name="csrf-param">
# <meta content
# <a class="city-name" href="/marseille">Marseille</a>
# </li>
# <li class="">
# <a class="city-name" href="/nantes">Nantes</a>
# </li>
# <li class="">
# <a class="city-name" href="/paris">Paris</a>
# </li>
# <li class="">
# <a class="city-name" href="/rennes">Rennes</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Europe</span>
# <ul>
# <li class="">
# <a class="city-name" href="/amsterdam">Amsterdam</a>
# </li>
# <li class="">
# <a class="city-name" href="/barcelona">Barcelona</a>
# </li>
# <li class="">
# <a class="city-name" href="/berlin">Berlin</a>
# </li>
# <li class="">
# <a class="city-name" href="/brussels">Brussels</a>
# </li>
# <li class="">
# <a class="city-name" href="/copenhagen">Copenhagen</a>
# </li>
# <li class="">
# <a class="city-name" href="/lausanne">Lausanne</a>
# </li>
# <li class="">
# <a class="city-name" href="/lisbon">Lisbon</a>
# </li>
# <li class="">
# <a class="city-name" href="/london">London</a>
# </li>
# <li class="">
# <a class="city-name" href="/madrid">Madrid</a>
# </li>
# <li class="">
# <a class="city-name" href="/milan">Milan</a>
# </li>
# <li class="">
# <a class="city-name" href="/oslo">Oslo</a>
# </li>
# <li class="">
# <a class="city-name" href="/rome">Rome</a>
# </li>
# <li class="">
# <a class="city-name" href="/stockholm">Stockholm</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Asia Pacific</span>
# <ul>
# <li class="">
# <a class="city-name" href="/bali">Bali</a>
# </li>
# <li class="">
# <a class="city-name" href="/chengdu">Chengdu</a>
# </li>
# <li class="">
# <a class="city-name" href="/kyoto">Kyoto</a>
# </li>
# <li class="">
# <a class="city-name" href="/melbourne">Melbourne</a>
# </li>
# <li class="">
# <a class="city-name" href="/seoul">Seoul</a>
# </li>
# <li class="">
# <a class="city-name" href="/shanghai">Shanghai</a>
# </li>
# <li class="">
# <a class="city-name" href="/shenzhen">Shenzhen</a>
# </li>
# <li class="">
# <a class="city-name" href="/singapore">Singapore</a>
# </li>
# <li class="">
# <a class="city-name" href="/tokyo">Tokyo</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Americas</span>
# <ul>
# <li class="">
# <a class="city-name" href="/belo-horizonte">Belo Horizonte</a>
# </li>
# <li class="">
# <a class="city-name" href="/buenos-aires">Buenos Aires</a>
# </li>
# <li class="">
# <a class="city-name" href="/mexico">Mexico</a>
# </li>
# <li class="">
# <a class="city-name" href="/montreal">Montreal</a>
# </li>
# <li class="">
# <a class="city-name" href="/rio">Rio de Janeiro</a>
# </li>
# <li class="">
# <a class="city-name" href="/sao-paulo">São Paulo</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Middle-East &amp; Africa</span>
# <ul>
# <li class="">
# <a class="city-name" href="/casablanca">Casablanca</a>
# </li>
# <li class="">
# <a class="city-name" href="/tel-aviv">Tel Aviv</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="other-ways">
# <a href="/campuses/map">
# <svg height="26" id="icon-map" version="1.1" viewbox="0 0 42 26" width="42" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g fill="none" fill-rule="evenodd" id="wireframes" stroke="none" stroke-width="1"><g fill-rule="nonzero" id="Bootcamp-dropdown" transform="translate(-208.000000, -393.000000)"><g id="List"><g id="icon-map" transform="translate(208.000000, 393.000000)"><path d="M41.3299091,21.9035556 L33.7579773,11.8401111 C33.50025,11.4997037 33.0668864,11.3668148 32.6612045,11.4823704 L29.3360455,12.519 C28.9131818,13.3803704 28.4487955,14.2345185 27.9696136,15.0674815 L32.5810227,13.6278519 L38.7340227,21.8096667 L28.8301364,23.5771852 L27.0985909,16.5518889 C26.8384773,16.9784815 26.5993636,17.3564444 26.3564318,17.7416296 L27.7725,23.490037 L16.3308409,21.6132222 L17.8428409,15.7853704 C17.5999091,15.3761111 17.3646136,14.9731111 17.1255,14.5421852 L15.31425,21.5337778 L3.79288636,23.2767407 L9.74781818,15.4921481 L16.7475,13.8363333 C16.4134091,13.2123333 16.1055682,12.597 15.8096591,11.973963 L8.94313636,13.6013704 C8.71738636,13.6533704 8.51597727,13.7828889 8.37709091,13.9697037 L0.67725,24.0321852 C0.428113636,24.362 0.396613636,24.8092963 0.604704545,25.1655926 C0.788454545,25.4775926 1.11825,25.6668148 1.47238636,25.6668148 C1.52059091,25.6668148 1.57261364,25.662963 1.62177273,25.6533333 L15.5715,23.542037 L28.4144318,25.6533333 C28.5327955,25.6706667 28.6435227,25.6706667 28.7547273,25.6494815 L40.7056364,23.5131481 C41.04975,23.4548889 41.3380227,23.2160741 41.4659318,22.8867407 C41.5900227,22.5593333 41.5413409,22.1832963 41.3299091,21.9035556 Z" fill="#4A4A4A" id="Shape"></path><path d="M22.69575,0.332703704 C19.1348182,0.332703704 16.2473182,3.24951852 16.2473182,6.84088889 C16.2473182,10.4351481 22.69575,19.6174815 22.69575,19.6174815 C22.69575,19.6174815 29.1489545,10.4351481 29.1489545,6.84088889 C29.1489545,3.24951852 26.2595455,0.332703704 22.69575,0.332703704 Z M22.69575,9.83377778 C21.0572727,9.83377778 19.7314091,8.49333333 19.7314091,6.84137037 C19.7314091,5.18555556 21.0572727,3.84414815 22.69575,3.84414815 C24.3366136,3.84414815 25.6658182,5.18555556 25.6658182,6.84137037 C25.6653409,8.49333333 24.3366136,9.83377778 22.69575,9.83377778 Z" fill="#DDD5C3" id="Shape"></path></g></g></g></g></svg>
#         View the map
# </a> <a href="/campuses">See all campuses</a>
# </div>
# </div>
# </li>
# <li>
# <a href="/program">Program</a>
# </li>
# <li>
# <a href="/graduates">Graduates</a>
# </li>
# </ul>
# </div>
# <div class="navbar-container">
# <ul>
# <li>
# <a href="/events">Events</a>
# </li>
# <li>
# <a href="/career-services">Career services</a>
# </li>
# </ul>
# <a class="cta cta-secondary" href="/campuses">Select a city</a>
# </div>
# </nav>
# <section class="wrapper wrapper-top">
# <h1>Find your campus among <i class="highlighted highlighted-red">37 cities</i></h1>
# <p>Le Wagon is a global community with campuses all around the world. Each city has its own ecosystem and network of graduates: explore them and choose the one that is made for you!</p>
# </section>
# <section class="wrapper" data-controller="cities">
# <div class="city-selection">
# <div class="city-filters">
# <div class="main-filters">
# <a class="active" href="/campuses">List</a>
# <a href="/campuses/map">Map</a>
# </div>
# <div class="list-filters">
# <div class="dropdown-container" data-controller="dropdown">
# <div class="dropdown-trigger" data-action="click-&gt;dropdown#toggleDropdown click@window-&gt;dropdown#hideDropdown" data-selected="all" data-target="cities.regionFilter">
#         All regions
#       </div>
# <ul class="dropdown-content hidden" data-target="dropdown.dropdownContent">
# <li data-action="click-&gt;cities#selectRegion click-&gt;dropdown#hide" data-name="all">
#           All regions
#         </li>
# <li data-action="click-&gt;cities#selectRegion click-&gt;dropdown#hide" data-name="france">
#             France
#           </li>
# <li data-action="click-&gt;cities#selectRegion click-&gt;dropdown#hide" data-name="europe">
#             Europe
#           </li>
# <li data-action="click-&gt;cities#selectRegion click-&gt;dropdown#hide" data-name="asia pacific">
#             Asia Pacific
#           </li>
# <li data-action="click-&gt;cities#selectRegion click-&gt;dropdown#hide" data-name="americas">
#             Americas
#           </li>
# <li data-action="click-&gt;cities#selectRegion click-&gt;dropdown#hide" data-name="middle-east &amp; africa">
#             Middle-East &amp; Africa
#           </li>
# </ul>
# </div>
# <div class="dropdown-container" data-controller="dropdown">
# <div class="dropdown-trigger" data-action="click-&gt;dropdown#toggleDropdown click@window-&gt;dropdown#hideDropdown" data-selected="all" data-target="cities.languageFilter">
#         All course languages
#       </div>
# <ul class="dropdown-content hidden" data-target="dropdown.dropdownContent">
# <li data-action="click-&gt;cities#selectLanguage click-&gt;dropdown#hide" data-name="all">
#           All course languages
#         </li>
# <li data-action="click-&gt;cities#selectLanguage click-&gt;dropdown#hide" data-name="en">
#             English
#           </li>
# <li data-action="click-&gt;cities#selectLanguage click-&gt;dropdown#hide" data-name="fr">
#             French
#           </li>
# <li data-action="click-&gt;cities#selectLanguage click-&gt;dropdown#hide" data-name="es">
#             Spanish
#           </li>
# <li data-action="click-&gt;cities#selectLanguage click-&gt;dropdown#hide" data-name="pt-BR">
#             Portuguese
#           </li>
# <li data-action="click-&gt;cities#selectLanguage click-&gt;dropdown#hide" data-name="zh-CN">
#             Chinese
#           </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="city-cards" data-target="cities.list">
# <a class="city-card-link" data-languages='["en"]' data-region="middle-east &amp; africa" data-target="cities.city" href="/tel-aviv">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541765086/xnq7sxknj6mcu2skxxiq.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541765086/xnq7sxknj6mcu2skxxiq.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1541765086/xnq7sxknj6mcu2skxxiq.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Tel Aviv</h3>
# <span>Dec 20, 2019</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["fr"]' data-region="france" data-target="cities.city" href="/bordeaux">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1540215989/hlo1wgs9ld7owxuvedgk.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1540215989/hlo1wgs9ld7owxuvedgk.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1540215989/hlo1wgs9ld7owxuvedgk.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Bordeaux</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in French
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["en"]' data-region="europe" data-target="cities.city" href="/copenhagen">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1551886970/fdi18l7yjhysq5bnbmsa.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1551886970/fdi18l7yjhysq5bnbmsa.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1551886970/fdi18l7yjhysq5bnbmsa.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Copenhagen</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["fr"]' data-region="europe" data-target="cities.city" href="/lausanne">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1572341312/k01b3br5vjgscatx7yvv.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1572341312/k01b3br5vjgscatx7yvv.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1572341312/k01b3br5vjgscatx7yvv.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>
jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1555338977/nfnykzg082xq06swn4lu.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Milan</h3>
# <span>Feb 17, 2020</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["fr"]' data-region="france" data-target="cities.city" href="/rennes">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1571823264/ezrzgu6zyaalvaxdkhgg.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1571823264/ezrzgu6zyaalvaxdkhgg.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1571823264/ezrzgu6zyaalvaxdkhgg.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Rennes</h3>
# <span>Feb 24, 2020</span>
# </div>
# <p>
#               Course in French
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["en"]' data-region="asia pacific" data-target="cities.city" href="/chengdu">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1563353102/acmraibmtiztqfvkjpdb.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1563353102/acmraibmtiztqfvkjpdb.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1563353102/acmraibmtiztqfvkjpdb.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Chengdu</h3>
# <span>Mar 16, 2020</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["fr"]' data-region="france" data-target="cities.city" href="/lille">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541511178/qn3ubext1jpwfvj1yjtz.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541511178/qn3ubext1jpwfvj1yjtz.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1541511178/qn3ubext1jpwfvj1yjtz.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Lille</h3>
# <span>Apr  6, 2020</span>
# </div>
# <p>
#               Course in French
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["en","zh-CN"]' data-region="asia pacific" data-target="cities.city" href="/shenzhen">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1571800804/ymjnzymk85qhjjgeleil.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1571800804/ymjnzymk85qhjjgeleil.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1571800804/ymjnzymk85qhjjgeleil.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Shenzhen</h3>
# <span>Apr 20, 2020</span>
# </div>
# <p>
#               Course in English, Chinese
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["en"]' data-region="middle-east &amp; africa" data-target="cities.city" href="/casablanca">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1546352609/cpcnyhphgkrvmerog5jw.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1546352609/cpcnyhphgkrvmerog5jw.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1546352609/cpcnyhphgkrvmerog5jw.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Casablanca</h3>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>
# </a> <a class="city-card-link" data-languages='["en"]' data-region="asia pacific" data-target="cities.city" href="/kyoto">
# <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1562201968/ao7brcgxatxxsqx9hcfq.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1562201968/ao7brcgxatxxsqx9hcfq.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1562201968/ao7brcgxatxxsqx9hcfq.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Kyoto</h3>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>
# </a>
# </div>
# <div class="empty-list hidden" data-target="cities.emptyList">
# <p>Oops, we don't have any campuses matching your current request. <i data-action="click-&gt;cities#resetFilters" data-language="All course languages" data-name="all" data-region="All continents">Try something else!</i></p>
# </div>
# </div>
# </section>
# <section class="wrapper your-city">
# <h2>Could your city be the next one?</h2>
# <p>If you are looking to bring Le Wagon into your local tech ecosystem and bring forward new ideas to build the future of education, reach out!</p>
# <a class="cta cta-big cta-primary" href="mailto:contact@lewagon.com">Submit your city</a>
# </section>
# <footer>
# <div class="wrapper">
# <div class="newsletter-container" data-controller="newsletter">
# <span class="newsletter-info">Let's keep in touch!</span>
# <p>Stay up to date on Le Wagon events and coding workshops in your city</p>
# <form accept-charset="UTF-8" action="#" class="simple_form form-inline" id="newsletter-form" method="post" novalidate="novalidate"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="SADzBNrbzTNMcYfxecRxMSek4nQynRA5tYwDfdZesS+Dbj2Z8IIfGQ2/xCxG6IyIpwmDvPbWzbnvPKS28MaUUw=="/>
# <div class="form-group email optional prospect_email"><input class="form-control string email optional" data-target="newsletter.emailInput" id="prospect_email" name="prospect[email]" placeholder="alan@turing.com" type="email"/></div>
# <div class="dropdown-form-wrapper" data-controller="dropdown dropdown-form">
# <div class="dropdown-form-summary" data-action="click-&gt;dropdown#toggleDropdown click@window-&gt;dropdown#hideDropdown" data-target="dropdown-form.trigger">
#           Paris
#         </div>
# ...
# </div>
# <input class="cta cta-big cta-primary" data-disable-with="Posting..." name="commit" type="submit" value="Subscribe"/>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class
42075413 39.2161971,7.42075413 L42.2354187,7.42075413 C42.4495389,7.42075413 42.6398793,7.55712752 42.7087378,7.75987364 L45.6028022,16.2811202 C45.647193,16.4118237 45.7891348,16.481794 45.9198383,16.4374033 C45.9933872,16.4124239 46.051142,16.3546692 46.0761214,16.2811202 L48.9701858,7.75987364 C49.0390443,7.55712752 49.2293847,7.42075413 49.4435049,7.42075413 L52.1222417,7.42075413 C52.3983137,7.42075413 52.6221142,7.64455468 52.6221142,7.92062665 C52.6221142,7.97530259 52.613144,8.02960814 52.5955608,8.08137967 L47.8227222,22.1344652 C47.7538637,22.3372113 47.5635234,22.4735847 47.3494031,22.4735847 L44.3295205,22.4735847 C44.1154003,22.4735847 43.9250599,22.3372113 43.8562014,22.1344652 L40.9624675,13.6141918 C40.9180768,13.4834883 40.7761349,13.413518 40.6454314,13.4579087 C40.5718825,13.4828881 40.5141277,13.5406428 40.4891483,13.6141918 L37.5954145,22.1344652 C37.5265559,22.3372113 37.3362156,22.4735847 37.1220953,22.4735847 Z M65.2304527,21.585789 C63.9536215,22.4626978 62.4107084,22.9753457 60.7489712,22.9753457 C56.3488754,22.9753457 52.781893,19.3810088 52.781893,14.9471694 C52.781893,10.5133301 56.3488754,6.91899311 60.7489712,6.91899311 C62.4107084,6.91899311 63.9536215,7.43164104 65.2304527,8.3085498 L65.2304527,7.92251515 C65.2304527,7.64540019 65.4533891,7.420754 ...
# <p>We’re bringing tech skills to creative people</p>
# <div class="dropdown-selector" data-controller="dropdown">
# <button class="dropdown-trigger" data-action="click-&gt;dropdown#toggleDropdown click@window-&gt;dropdown#hideDropdown">
#         🇬🇧 English
#     <svg class="carret" data-target="dropdown.carret" height="3" viewbox="0 0 8 3" width="8" xmlns="http://www.w3.org/2000/svg"><path d="m66.3706055 9 2.8516167 3 2.7777778-3" fill="none" stroke="#42464c" stroke-linecap="round" stroke-linejoin="round" transform="translate(-65 -9)"></path></svg>
# </button>
# <ul class="dropdown-trigger-content hidden" data-controller="locales" data-locales='[{"name":"English","iso":"en","slug":"en","emoji_flag":"🇬🇧","published":true,"countrycode":"gb","dialcode":"+44","phoneplaceholder":"+447 123 456789"},{"name":"French","iso":"fr","slug":"fr","emoji_flag":"🇫🇷","published":true,"countrycode":"fr","dialcode":"+33","phoneplaceholder":"+33 6 12 34 56 78"},{"name":"Spanish","iso":"es","slug":"es","emoji_flag":"🇪🇸","published":true,"countrycode":"es","dialcode":"+34","phoneplaceholder":"+34 1234567"},{"name":"German","iso":"de","slug":"de","emoji_flag":"🇩🇪","published":true,"countrycode":"de","dialcode":"+49","phoneplaceholder":"+49 30 12345678"},{"name":"Portuguese","iso":"pt-BR","slug":"pt_br","emoji_flag":"🇵🇹","published":true,"countrycode":"pt","dialcode":"+351","phoneplaceholder":"+351 123 456 78"},{"name":"Italian","iso":"it","slug":"it","emoji_flag":"🇮🇹","published":true,"countrycode":"it","dialcode":"+39","phoneplaceholder":"+391234567890"},{"name":"Japanese","iso":"ja","slug":"ja","emoji_flag":"🇯🇵","published":true,"countrycode":"jp","dialcode":"+81","phoneplaceholder":"+81 90 1234 5678"},{"name":"Chinese","iso":"zh-CN","slug":"zh_cn","emoji_flag":"🇨🇳","published":true,"countrycode":"cn","dialcode":"+86","phoneplaceholder":"+86 12345678901"}]' data-nofollow="false" data-target="locales.localeLinks dropdown.dropdownContent" data-url="/LOCALE/campuses">
# </ul>
# </div>
# </div>
# <div class="column global-links">
# <span>About us</span>
# <ul>
# <li><a href="/faq">FAQ</a></li>
#
#           <li><a href="/press">Press</a></li>
#
#           <li><a href="https://www.iubenda.com/privacy-policy/7967062/legal" rel="nofollow noopener" target="_blank">Privacy Policy</a></li>
#
#           <li><a href="/team">Our team</a></li>
#
#           <li><a href="/contact">Contact us</a></li>
#
#         </ul>
# </div>
# <div class="column global-links">
# <span>Resources</span>
# <ul>
# <li><a href="/blog">Blog</a></li>
#
#           <li><a href="https://medium.com/le-wagon" rel="nofollow noopener" target="_blank">Medium</a></li>
#
#             <li><a href="https://shows.pippa.io/lewagon-live" rel="nofollow noopener" target="_blank">Podcast</a></li>
# </ul>
# </div>
# <div class="column global-links">
# <span>Corporate</span>
# <ul>
# <li><a href="https://executive.lewagon.com">Le Wagon executive</a></li>
#
#         </ul>
# </div>
# <div class="column global-links">
# <span>Follow us</span>
# <ul>
# <li><a href="https://www.instagram.com/lewagonparis" rel="nofollow noopener" target="_blank">Instagram</a></li>
#
#             <li><a href="https://www.twitter.com/lewagonlondon" rel="nofollow noopener" target="_blank">Twitter</a></li>
#
#             <li><a href="https://www.facebook.com/lewagon" rel="nofollow noopener" target="_blank">Facebook</a></li>
#
#           <li><a href="https://www.linkedin.com/school/le-wagon/" rel="nofollow noopener" target="_blank">Linkedin</a></li>
#
#           <li><a href="https://www.youtube.com/le-wagon" rel="nofollow noopener" target="_blank">YouTube</a></li>
#
#             <li><a href="https://www.meetup.com/pro/lewagon/ " rel="nofollow noopener" target="_blank">Meetup</a></li>
#
#         </ul>
# </div>
# </div>
# </div>
# <div class="wrapper">
# <div class="footer-section">
# <div class="column">
# <span>France</span>
# <ul>
# <li>
# <a class="city-name" href="/bordeaux">Bordeaux</a>
# </li>
# <li>
# <a class="city-name" href="/lille">Lille</a>
# </li>
# <li>
# <a class="city-name" href="/lyon">Lyon</a>
# </li>
# <li>
# <a class="city-name" href="/marseille">Marseille</a>
# </li>
# <li>
# <a class="city-name" href="/nantes">Nantes</a>
# </li>
# <li>
# <a class="city-name" href="/paris">Paris</a>
# </li>
# <li>
# <a class="city-name" href="/rennes">Rennes</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Europe</span>
# <ul>
# <li>
# <a class="city-name" href="/amsterdam">Amsterdam</a>
# </li>
# <li>
# <a class="city-name" href="/barcelona">Barcelona</a>
# </li>
# <li>
# <a class="city-name" href="/berlin">Berlin</a>
# </li>
# <li>
# <a class="city-name" href="/brussels">Brussels</a>
# </li>
# <li>
# <a class="city-name" href="/copenhagen">Copenhagen</a>
# </li>
# <li>
# <a class="city-name" href="/lausanne">Lausanne</a>
# </li>
# <li>
# <a class="city-name" href="/lisbon">Lisbon</a>
# </li>
# <li>
# <a class="city-name" href="/london">London</a>
# </li>
# <li>
# <a class="city-name" href="/madrid">Madrid</a>
# </li>
# <li>
# <a class="city-name" href="/milan">Milan</a>
# </li>
# <li>
# <a class="city-name" href="/oslo">Oslo</a>
# </li>
# <li>
# <a class="city-name" href="/rome">Rome</a>
# </li>
# <li>
# <a class="city-name" href="/stockholm">Stockholm</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Asia Pacific</span>
# <ul>
# <li>
# <a class="city-name" href="/bali">Bali</a>
# </li>
# <li>
# <a class="city-name" href="/chengdu">Chengdu</a>
# </li>
# <li>
# <a class="city-name" href="/kyoto">Kyoto</a>
# </li>
# <li>
# <a class="city-name" href="/melbourne">Melbourne</a>
# </li>
# <li>
# <a class="city-name" href="/seoul">Seoul</a>
# </li>
# <li>
# <a class="city-name" href="/shanghai">Shanghai</a>
# </li>
# <li>
# <a class="city-name" href="/shenzhen">Shenzhen</a>
# </li>
# <li>
# <a class="city-name" href="/singapore">Singapore</a>
# </li>
# <li>
# <a class="city-name" href="/tokyo">Tokyo</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Americas</span>
# <ul>
# <li>
# <a class="city-name" href="/belo-horizonte">Belo Horizonte</a>
# </li>
# <li>
# <a class="city-name" href="/buenos-aires">Buenos Aires</a>
# </li>
# <li>
# <a class="city-name" href="/mexico">Mexico</a>
# </li>
# <li>
# <a class="city-name" href="/montreal">Montreal</a>
# </li>
# <li>
# <a class="city-name" href="/rio">Rio de Janeiro</a>
# </li>
# <li>
# <a class="city-name" href="/sao-paulo">São Paulo</a>
# </li>
# </ul>
# </div>
# <div class="column">
# <span>Middle-East &amp; Africa</span>
# <ul>
# <li>
# <a class="city-name" href="/casablanca">Casablanca</a>
# </li>
# <li>
# <a class="city-name" href="/tel-aviv">Tel Aviv</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <style type="text/css">
#   #iubenda-cs-banner {
#     bottom: 0px !important;
#     left: 0px !important;
#     position: fixed !important;
#     z-index: 99999998 !important;
#     width: 100% !important;
#     margin: 0 auto !important;
#   }
#   @media(max-width: 520px) {
#     #iubenda-cs-banner {
#       width: 100% !important;
#     }
#   }
#  .iubenda-cs-content {
#     display: block;
#     margin: 0 auto;
#     padding: 15px;
#     width: auto;
#     font-family: Helvetica,Arial,FreeSans,sans-serif;
#     font-size: 12px;
#     background: #333;
#   }
#   .iubenda-cs-rationale {
#     max-width: 900px;
#     position: relative;
#     margin: 0 auto;
#   }
#   .iubenda-banner-content > p {
#     margin: 0 0 6px;
#     font-size: 12px;
#     font-family: Helvetica,Arial,FreeSans,sans-serif;
#     line-height: 1.5;
#     color: #fff !important;
#   }
#   .iubenda-cs-close-btn {
#     margin:0;
#     color: #fff;
#     text-decoration: none;
#     font-size: 26px;
#     position: absolute;
#     top: 0;
#     right: 0;
#     border: none;
#   }
#   .iubenda-cs-cookie-policy-lnk {
#     text-decoration: underline;
#     color: #fff;
#     font-size: 12px;
#     font-weight: 900;
#   }
# </style>
# <script type="text/javascript">
#   var _iub = _iub || [];
#   _iub.csConfiguration = {
#     cookiePolicyId: 7967062,
#     siteId: 662533,
#     lang: "en",
#     banner: {
#       slideDown: false,
#       applyStyles: false
#     }
#   };
# </script>
# <script async="" charset="UTF-8" src="//cdn.iubenda.com/cookie_solution/safemode/iubenda_cs.js" type="text/javascript"></script>
# <script async="async" src="https://dwj199mwkel52.cloudfront.net/packs/frontend_desktop-bca7fa24806827224cd2.js"></script>
# <script class="_iub_cs_activate-inline" type="text/plain">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-39720822-1', 'lewagon.com');
#   ga('require', 'linkid');
#   ga('send', 'pageview');
# </script>
# <script class="_iub_cs_activate-inline" type="text/plain">
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '751967801553090');
#   fbq('track', 'PageView');
# </script>
# <script class="_iub_cs_activate-inline" type="text/plain">
# _linkedin_partner_id = "951300";
# window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
# window._linkedin_data_partner_ids.push(_linkedin_partner_id);
# </script><script type="text/javascript">
# (function(){var s = document.getElementsByTagName("script")[0];
# var b = document.createElement("script");
# b.type = "text/javascript";b.async = true;
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
# s.parentNode.insertBefore(b, s);})();
# </script>
# <noscript>
# <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=951300&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <!-- Hotjar Tracking Code for https://www.lewagon.com -->
# <script class="_iub_cs_activate-inline" type="text/plain">
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:376674,hjsv:5};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
# <script class="_iub_cs_activate-inline" id="hs-script-loader" src="https:////js.hs-scripts.com/4419217.js" type="text/plain"></script>
# </body>
# </html>

# %% [markdown]
# ## Getting all the cities based on the class name

# %%
cities = soup.find_all(class_='city-card')

# %%
print(cities)
# Out:
# [<div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541765086/xnq7sxknj6mcu2skxxiq.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541765086/xnq7sxknj6mcu2skxxiq.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1541765086/xnq7sxknj6mcu2skxxiq.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Tel Aviv</h3>
# <span>Dec 20, 2019</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>, <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1540215989/hlo1wgs9ld7owxuvedgk.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1540215989/hlo1wgs9ld7owxuvedgk.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1540215989/hlo1wgs9ld7owxuvedgk.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Bordeaux</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in French
#             </p>
# </div>
# </div>, <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1551886970/fdi18l7yjhysq5bnbmsa.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1551886970/fdi18l7yjhysq5bnbmsa.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1551886970/fdi18l7yjhysq5bnbmsa.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Copenhagen</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>, <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1572341312/k01b3br5vjgscatx7yvv.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1572341312/k01b3br5vjgscatx7yvv.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1572341312/k01b3br5vjgscatx7yvv.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Lausanne</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in French
#             </p>
# </div>
# </div>, <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1548262236/rkpigus1xtlwjsyyk055.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1548262236/rkpigus1xtlwjsyyk055.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1548262236/rkpigus1xtlwjsyyk055.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Oslo</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>, <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1542723646/lbxd30bqefwakucqo8ts.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1542723646/lbxd30bqefwakucqo8ts.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1542723646/lbxd30bqefwakucqo8ts.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Paris</h3>
# <span>Jan  6, 2020</span>
# </div>
# <p>
#               Course in French
#             </p>
# </div>
# </div>, <div class="city-card">
# <div class="city-card-cover" style="      background-image: url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1553535496/uwql4jw6gpqgeozpfa2o.jpg);
#       background-image: -webkit-image-set(url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1553535496/uwql4jw6gpqgeozpfa2o.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1553535496/uwql4jw6gpqgeozpfa2o.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>
(https://res.cloudinary.com/wagon/image/upload/c_fill,h_320,q_auto,w_540/v1541765086/xnq7sxknj6mcu2skxxiq.jpg) 1x, url(https://res.cloudinary.com/wagon/image/upload/c_fill,h_640,q_auto,w_1080/v1541765086/xnq7sxknj6mcu2skxxiq.jpg) 2x);
# "></div>
# <div class="city-card-content">
# <div class="city-card-info">
# <h3>Tel Aviv</h3>
# <span>Dec 20, 2019</span>
# </div>
# <p>
#               Course in English
#             </p>
# </div>
# </div>

# %% [markdown]
# ## Getting different information from the city

# %%
city_name = first_city.find(class_='city-card-info').find('h3').string
city_language = first_city.find(class_='city-card-content').find('p').string.strip().strip('Course in ')
print(city_language)
# Out:
# English

# %% [markdown]
# ## Looping over all cities

# %%
cities_dict = {
    'names': [],
    'languages': []
}

for city in cities:
    city_name = city.find(class_='city-card-info').find('h3').string
    city_language = city.find(class_='city-card-content').find('p').string.strip().strip('Course in ')
    cities_dict['names'].append(city_name)
    cities_dict['languages'].append(city_language)
cities_dict
# Out:
# {'names': ['Tel Aviv',
#   'Bordeaux',
#   'Copenhagen',
#   'Lausanne',
#   'Oslo',
#   'Paris',
#   'Belo Horizonte',
#   'Mexico',
#   'Rio de Janeiro',
#   'São Paulo',
#   'Amsterdam',
#   'Berlin',
#   'Brussels',
#   'Buenos Aires',
#   'Lisbon',
#   'London',
#   'Lyon',
#   'Madrid',
#   'Melbourne',
#   'Montreal',
#   'Rome',
#   'Seoul',
#   'Tokyo',
#   'Nantes',
#   'Bali',
#   'Marseille',
#   'Barcelona',
#   'Singapore',
#   'Stockholm',
#   'Shanghai',
#   'Milan',
#   'Rennes',
#   'Chengdu',
#   'Lille',
#   'Shenzhen',
#   'Casablanca',
#   'Kyoto'],
#  'languages': ['English',
#   'French',
#   'English',
#   'French',
#   'English',
#   'French',
#   'Portug',
#   'English',
#   'English',
#   'Portug',
#   'English',
#   'English',
#   'English',
#   'English, Spanish',
#   'English',
#   'English',
#   'French',
#   'English',
#   'English',
#   'English',
#   'English',
#   'English',
#   'English',
#   'French',
#   'English',
#   'French',
#   'English',
#   'English',
#   'English',
#   'English',
#   'English',
#   'French',
#   'English',
#   'French',
#   'English, Ch',
#   'English',
#   'English']}

# %%
import pandas as pd
cities_df = pd.DataFrame(cities_dict)
cities_df
# Out:
#              names         languages
# 0         Tel Aviv           English
# 1         Bordeaux            French
# 2       Copenhagen           English
# 3         Lausanne            French
# 4             Oslo           English
# 5            Paris            French
# 6   Belo Horizonte            Portug
# 7           Mexico           English
# 8   Rio de Janeiro           English
# 9        São Paulo            Portug
# 10       Amsterdam           English
# 11          Berlin           English
# 12        Brussels           English
# 13    Buenos Aires  English, Spanish
# 14          Lisbon           English
# 15          London           English
# 16            Lyon            French
# 17          Madrid           English
# 18       Melbourne           English
# 19        Montreal           English
# 20            Rome           English
# 21           Seoul           English
# 22           Tokyo           English
# 23          Nantes            French
# 24            Bali           English
# 25       Marseille            French
# 26       Barcelona           English
# 27       Singapore           English
# 28       Stockholm           English
# 29        Shanghai           English
# 30           Milan           English
# 31          Rennes            French
# 32         Chengdu           English
# 33           Lille            French
# 34        Shenzhen       English, Ch
# 35      Casablanca           English
# 36           Kyoto           English

# %%
import matplotlib
# %matplotlib inline

# %%
group_by_languages = cities_df.groupby('languages').count()
group_by_languages
# Out:
#                   names
# languages
# English              25
# English, Ch           1
# English, Spanish      1
# French                8
# Portug                2

# %%
group_by_languages.plot(kind="bar")
